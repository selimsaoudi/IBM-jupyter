# %% [markdown]
# # Projet final science des données

# %% [markdown]
# ## Introduction
#
# Ce carnet Jupyter présente quelques notions de base en science des données.
# On y trouve les principaux langages utilisés, les bibliothèques les plus courantes,
# ainsi que quelques exemples simples de code en Python.

# %% [markdown]
# ## Langages de la science des données
#
# Voici quelques langages couramment utilisés en science des données :
#
# - **Python**
# - **R**
# - **SQL**
# - **Scala**
# - **Julia**

# %% [markdown]
# ## Bibliothèques de science des données
#
# Quelques bibliotheques très utilisées en science des données:
#
# - **NumPy** – calcul numérique et tableaux multidimensionnels
# - **pandas** – manipulation et analyse de données tabulaires
# - **Matplotlib** / **Seaborn** – visualisation de données
# - **scikit-learn** – apprentissage automatique (machine learning)
# - **TensorFlow** / **PyTorch** – deep learning

# %% [markdown]
# ## Outils de la science des données
#
# | Outil               | Catégorie              | Utilisation principale                              |
# |---------------------|------------------------|-----------------------------------------------------|
# | Jupyter Notebook    | Environnement interactif | Prototypage et expérimentation de code            |
# | Git / GitHub        | Gestion de version      | Suivi des modifications, travail collaboratif      |
# | VS Code             | Éditeur de code         | Développement et débogage                          |
# | Tableau / Power BI  | Visualisation           | Tableaux de bord et graphiques interactifs         |
# | Apache Spark        | Traitement distribué    | Analyse de gros volumes de données (big data)      |

# %% [markdown]
# ## Exemples d'expressions arithmétiques
#
# Voici quelques exemples d'expressions arithmétiques :
#
# - Addition : `3 + 5`
# - Soustraction : `10 - 4`
# - Multiplication : `6 * 7`
# - Division : `20 / 4`
# - Puissance : `2 ** 3`
# - Priorité des opérations : `2 + 3 * 4`

# %%
# Exercice 8 : multiplier et additionner des nombres

a= 6
b= 4

produit=a*b
somme=a+b

print("a =", a, "et b =", b)
print("Produit a * b =", produit)
print("Somme a + b   =", somme)
# Out:
# a = 6 et b = 4
# Produit a * b = 24
# Somme a + b   = 10

# %%
# Exercice 9 : convertir des minutes en heures

minutes= 135  # tu peux changer cette valeur pour tester

heures=minutes/60

print(minutes, "minutes correspondent à", heures, "heures.")
# Out:
# 135 minutes correspondent à 2.25 heures.

# %% [markdown]
# ## Objectifs du carnet
#
# Les objectifs de ce carnet sont :
#
# 1. Identifier les principaux langages utilisés en science des données.
# 2. Découvrir quelques bibliothèques populaires pour analyser les données.
# 3. Présenter quelques outils typiques du travail de data scientist.
# 4. Montrer des exemples simples d'expressions arithmétiques en Python.
# 5. Écrire et exécuter quelques cellules de code dans un carnet Jupyter.

# %% [markdown]
# ## Auteur
#
# Ce carnet a été réalisé par : **Selim Saoudi**

# %% [markdown]
# ## Lien GitHub
#
# Mon carnet est disponible publiquement ici :
# "github.com/selimsaoudi/IBM-jupyter"
